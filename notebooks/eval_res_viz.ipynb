# %% [markdown]
# This notebook is useful to load and visualize the forecasting results of a DVC experiment. The experiment must be run first.

# %%
import pandas as pd

# %%
predictions = pd.read_pickle("data/prediction_results.pkl")
predictions.plot()
# Out:
# <Axes: xlabel='time'>

# %%
predictions.loc["2013-05", :].plot()
# Out:
# <Axes: xlabel='time'>

# %%
day_num = 46
predictions.iloc[day_num * 24: (day_num + 1) * 24, :].plot()
# Out:
# <Axes: xlabel='time'>

# %%
daily_metrics = pd.read_csv("results_plot/daily_metrics.csv", index_col="index", 
                            parse_dates=True)

# %%
daily_metrics.loc[:, "nrmse"].plot()
# Out:
# <Axes: xlabel='index'>
